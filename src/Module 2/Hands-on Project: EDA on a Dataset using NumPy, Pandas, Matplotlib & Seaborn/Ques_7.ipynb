# %%
import pandas as pd
import seaborn as sns

# Load the iris dataset directly using Seaborn
iris_df = sns.load_dataset('iris')

# Group by 'species' and calculate the mean of each feature
average_features = iris_df.groupby('species').mean()

# Print the result
print(average_features)

# --- Optional: Visualize the grouped data ---
# You can create bar plots or other visualizations to compare the means

# Example: Bar plot of average sepal length by species
import matplotlib.pyplot as plt

average_features['sepal_length'].plot(kind='bar', color=['skyblue', 'lightcoral', 'lightgreen'])
plt.title('Average Sepal Length by Species')
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.show()

# You can adapt this for other features as well
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026
