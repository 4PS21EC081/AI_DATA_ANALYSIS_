# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset from a URL
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
column_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
iris_df = pd.read_csv(url, header=None, names=column_names)

# --- Basic Exploration ---

# 1. Display the first few rows of the dataframe
print("First 5 rows of the Iris dataset:")
print(iris_df.head())
print("\n")

# 2. Get a concise summary of the dataframe, including data types and non-null values
print("Information about the dataset:")
print(iris_df.info())
print("\n")

# 3. Generate descriptive statistics of the numerical columns
print("Descriptive statistics:")
print(iris_df.describe())
print("\n")

# 4. Check for missing values
print("Missing values:")
print(iris_df.isnull().sum())
print("\n")

# 5. Display the unique classes in the 'class' column
print("Unique classes:")
print(iris_df['class'].unique())
print("\n")

# --- Basic Visualization (Optional) ---

# 6. Create a pair plot to visualize relationships between all numerical features
sns.pairplot(iris_df, hue='class')
plt.suptitle("Pair Plot of Iris Dataset Features", y=1.02)
plt.show()

# 7. Create box plots to visualize the distribution of each feature per class
plt.figure(figsize=(12, 8))
for i, column in enumerate(column_names[:-1]):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(x='class', y=column, data=iris_df)
    plt.title(f'Box Plot of {column} by Class')
plt.tight_layout()
plt.show()
# Out:
# First 5 rows of the Iris dataset:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#
# Information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
#
#
# ...
