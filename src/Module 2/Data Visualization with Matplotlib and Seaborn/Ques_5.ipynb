# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Data from Question 2 (Height vs. Weight)
heights_in_cm = [160, 170, 165, 180, 175]
weights_in_kg = [55, 65, 60, 80, 76]

# Create the scatter plot using Seaborn
plt.figure(figsize=(8, 6)) # Optional: Adjust figure size
sns.scatterplot(x=heights_in_cm, y=weights_in_kg)

# Add labels and title
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.title('Relationship between Height and Weight (Seaborn)')

# Add grid lines (optional, but often helpful for scatter plots)
plt.grid(True)

# Display the plot
plt.show()
