# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager

# Data from Question 1
products = ['A', 'B', 'C', 'D', 'E']
sales_in_thousands = [23, 75, 57, 90, 65]

# --- Customization ---

# 1. Choose a different color for the bars
bar_color = 'skyblue'

# 2. Add a grid
plt.figure(figsize=(8, 6))
plt.grid(axis='y', linestyle='--') # Add a horizontal grid

# 3. Use custom fonts
title_font = {'fontname':'Arial', 'size':'16', 'color':'darkblue', 'weight':'bold'}
label_font = {'fontname':'Times New Roman', 'size':'12', 'color':'darkgreen'}

# Create the bar plot with customizations
plt.bar(products, sales_in_thousands, color=bar_color)

# Add labels and title with custom fonts
plt.xlabel('Products', **label_font)
plt.ylabel('Sales (in thousands)', **label_font)
plt.title('Number of Sales for Each Product', **title_font)

# Add the exact sales figures on top of the bars
for product, sale in zip(products, sales_in_thousands):
    plt.text(product, sale, str(sale), ha='center', va='bottom')

# Display the plot
plt.show()

# --- Optional: Explore available fonts ---
# print(font_manager.findfont('Arial', fallback_to_default=False))
# print(font_manager.findfont('Calibri', fallback_to_default=False))
# print([f.name for f in font_manager.fontManager.ttflist])
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# ...
