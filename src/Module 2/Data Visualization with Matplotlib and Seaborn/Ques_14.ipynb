# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# --- Customizing the Line Plot ---

# 1. Set figure size and style
plt.figure(figsize=(10, 6))
plt.style.use('seaborn-v0_8-whitegrid')  # Try other styles like 'ggplot', 'dark_background'

# 2. Plot the first line with custom color, linestyle, and marker
plt.plot(x, y1, color='teal', linestyle='-', linewidth=2, marker='o', markersize=6, label='Sine')

# 3. Plot the second line with different color, linestyle, and marker
plt.plot(x, y2, color='coral', linestyle='--', linewidth=1.5, marker='x', markersize=5, label='Cosine')

# 4. Customize labels and title with font properties
title_font = {'fontname': 'Arial', 'size': '16', 'color': 'darkblue', 'weight': 'bold'}
label_font = {'fontname': 'Calibri', 'size': '12', 'color': 'darkgreen'}
plt.xlabel('X-axis', **label_font)
plt.ylabel('Y-axis', **label_font)
plt.title('Sine and Cosine Waves', **title_font)

# 5. Add a legend
plt.legend(fontsize=10)

# 6. Add grid lines (optional, but often useful)
plt.grid(True, linestyle=':', alpha=0.7)

# 7. Set axis limits (optional)
plt.xlim(0, 10)
plt.ylim(-1.2, 1.2)

# 8. Add annotations (optional)
plt.annotate('Peak of Sine', xy=(np.pi/2, 1), xytext=(3, 1.1),
             arrowprops=dict(facecolor='black', shrink=0.05),
             fontsize=10)

# 9. Save the figure (optional)
# plt.savefig('customized_line_plot.png')

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
