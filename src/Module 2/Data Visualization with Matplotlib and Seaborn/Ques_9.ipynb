# %%
import matplotlib.pyplot as plt

# Data for the bar plot (from Question 1)
products = ['A', 'B', 'C', 'D', 'E']
sales_in_thousands = [23, 75, 57, 90, 65]

# Data for the scatter plot (from Question 2)
heights_in_cm = [160, 170, 165, 180, 175]
weights_in_kg = [55, 65, 60, 80, 76]

# Create a figure and a set of subplots (1 row, 2 columns)
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# --- First Subplot: Bar Plot for Product Sales ---
axes[0].bar(products, sales_in_thousands, color='skyblue')
axes[0].set_xlabel('Products')
axes[0].set_ylabel('Sales (in thousands)')
axes[0].set_title('Product Sales')
axes[0].grid(axis='y', linestyle='--')
for product, sale in zip(products, sales_in_thousands):
    axes[0].text(product, sale, str(sale), ha='center', va='bottom')

# --- Second Subplot: Scatter Plot for Height vs. Weight ---
axes[1].scatter(heights_in_cm, weights_in_kg, color='salmon', marker='o')
axes[1].set_xlabel('Height (cm)')
axes[1].set_ylabel('Weight (kg)')
axes[1].set_title('Height vs. Weight')
axes[1].grid(True)

# Adjust layout to prevent overlapping titles/labels
plt.tight_layout()

# Display the plot
plt.show()
