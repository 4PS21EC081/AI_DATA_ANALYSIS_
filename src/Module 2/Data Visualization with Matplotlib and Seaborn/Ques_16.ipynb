# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Sample data for different plot types
x = np.linspace(0, 10, 100)
y_sin = np.sin(x)
y_cos = np.cos(x)
student_marks = [23, 45, 56, 78, 89, 90, 67, 88, 76, 59]
products = ['A', 'B', 'C', 'D', 'E']
sales_in_thousands = [23, 75, 57, 90, 65]
iris_df = sns.load_dataset('iris')

# --- Combining Plots using Subplots ---

# Create a figure with multiple subplots (2 rows, 2 columns)
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
fig.suptitle('Combined Plots using Matplotlib Subplots', fontsize=16, fontweight='bold')

# Subplot 1: Line Plot (Sine and Cosine)
axes[0, 0].plot(x, y_sin, label='Sine', color='teal')
axes[0, 0].plot(x, y_cos, label='Cosine', color='coral')
axes[0, 0].set_xlabel('X-axis')
axes[0, 0].set_ylabel('Y-axis')
axes[0, 0].set_title('Line Plot: Sine and Cosine')
axes[0, 0].legend()
axes[0, 0].grid(True, linestyle='--', alpha=0.6)

# Subplot 2: Histogram (Student Marks)
axes[0, 1].hist(student_marks, bins=5, edgecolor='black', color='skyblue')
axes[0, 1].set_xlabel('Marks')
axes[0, 1].set_ylabel('Frequency')
axes[0, 1].set_title('Histogram: Student Marks')
axes[0, 1].grid(axis='y', linestyle='--', alpha=0.6)

# Subplot 3: Bar Plot (Product Sales)
axes[1, 0].bar(products, sales_in_thousands, color='lightgreen')
axes[1, 0].set_xlabel('Products')
axes[1, 0].set_ylabel('Sales (in thousands)')
axes[1, 0].set_title('Bar Plot: Product Sales')
axes[1, 0].grid(axis='y', linestyle='--', alpha=0.6)

# Subplot 4: Scatter Plot (Sepal Length vs. Sepal Width from Iris)
axes[1, 1].scatter(iris_df['sepal_length'], iris_df['sepal_width'], color='salmon', alpha=0.7)
axes[1, 1].set_xlabel('Sepal Length (cm)')
axes[1, 1].set_ylabel('Sepal Width (cm)')
axes[1, 1].set_title('Scatter Plot: Sepal Length vs. Sepal Width')
axes[1, 1].grid(True, linestyle='--', alpha=0.6)

# Adjust layout to prevent overlapping titles/labels
plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust for suptitle

# Display the combined plot
plt.show()
